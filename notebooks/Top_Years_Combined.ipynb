# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/katiegarrett/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
top_2014_final = pd.read_csv('../data/top_2014_final.csv')
top_2015_final = pd.read_csv('../data/top_2015_final.csv')
top_2016_final = pd.read_csv('../data/top_2016_final.csv')
top_2017_final = pd.read_csv('../data/top_2017_final.csv')
top_2018_final = pd.read_csv('../data/top_2018_final.csv')
top_2019_final = pd.read_csv('../data/top_2019_final.csv')
top_2020_final = pd.read_csv('../data/top_2020_final.csv')
top_2021_final = pd.read_csv('../data/top_2021_final.csv')
top_2022_final = pd.read_csv('../data/top_2022_final.csv')

# %%
all_years_final = pd.concat([top_2014_final, top_2015_final,top_2016_final, top_2017_final, top_2018_final, top_2019_final, top_2020_final, top_2021_final, top_2022_final  ],  join='inner')

display(all_years_final)
# Out:
#      Unnamed: 0            author  created_utc                       date  \
# 0             0         [deleted]   1408193703  2014-08-16 12:55:03+00:00
# 1             1     lolwuthahaomg   1418349360  2014-12-12 01:56:00+00:00
# 2             2         icookmath   1408493028  2014-08-20 00:03:48+00:00
# 3             3         [deleted]   1395938159  2014-03-27 16:35:59+00:00
# 4             4      Brad_Collins   1408377360  2014-08-18 15:56:00+00:00
# ..          ...               ...          ...                        ...
# 248         248     MF-ingTeacher   1653008912  2022-05-20 01:08:32+00:00
# 249         249     Medieval-Mind   1653009049  2022-05-20 01:10:49+00:00
# 250         250  InevitableSignUp   1653008698  2022-05-20 01:04:58+00:00
# 251         251     MF-ingTeacher   1653008912  2022-05-20 01:08:32+00:00
# 252         252  InevitableSignUp   1653008698  2022-05-20 01:04:58+00:00
#
#                                               combined  row_id  \
# ...

# %%
print(type(all_years_final))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
comment_words = ''
stopwords = set(STOPWORDS)

# %%
# iterate through the csv file
for val in all_years_final.combined:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8,14), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
wordcloud2 = WordCloud(width = 1400, height = 800,
                background_color ='white',
                stopwords = stopwords,
                colormap='Oranges',
                collocations=False,
                max_words=100,
                min_word_length = 4,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8,14), facecolor = None)
plt.imshow(wordcloud2)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
plt.savefig('wordmap.png')
